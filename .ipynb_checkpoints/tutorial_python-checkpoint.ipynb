# %%
import numpy as np
import math as m
import matplotlib.pylab as plt
import astropy.io.fits as fits
import os

# %matplotlib inline

# %%
pwd
# Out:
# '/Users/Zoe/Documents/GitHub/transit_demo/shebby_star'

# %%
filepath =  "/Users/Zoe/Documents/GitHub/transit_demo/shebby_star/"

# %%
filename = os.listdir(filepath)
filename[4]
# Out:
# 'HARPS.2018-05-07T033904.309_s1d_A.fits'

# %%
hdul = fits.open(filepath+filename[4])

# %%
hdul.info()
# Out:
# Filename: /Users/Zoe/Documents/GitHub/transit_demo/shebby_star/HARPS.2018-05-07T033904.309_s1d_A.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    3048   (313099,)   float32

# %%
array_of_data = hdul[0].data

# %%
plt.plot(array_of_data)
#plt.ylim(4000, 8000)

# %%
len(array_of_data)
# Out:
# 313099

# %% [markdown]
# # explore the header

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    1 / number of data axes
# NAXIS1  =               313099 / length of data axis 1
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# CRPIX1  =                   1. / Reference pixel
# CRVAL1  =              3781.83 / Coordinate at reference pixel
# CDELT1  =                 0.01 / Coordinate increment par pixel
# CTYPE1  = 'Angstrom'           / Units of coordinate
# BUNIT   = 'Relative Flux'      / Units of data values
# ORIGIN  = 'TEST    '                    / European Southern Observatory
# DATE    = '2018-05-07T03:49:06.017'     / UT date when this file was written
# TELESCOP= 'ESO-3P6 '                    / ESO Telescope Name
# ...

# %%
minval = hdul[0].header["CRVAL1"]
maxval = minval + len(array_of_data)*hdul[0].header["CDELT1"]
maxval

wavelengths= np.arange(len(array_of_data))*0.01#+minval

# %%
wavelengths+hdul[0].header["CRVAL1"]
# Out:
# array([3781.83, 3781.84, 3781.85, ..., 6912.79, 6912.8 , 6912.81])

# %%
len(array_of_data)
# Out:
# 313099
